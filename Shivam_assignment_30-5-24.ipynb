# %%
# importing libraries
import numpy as np 
import pandas as pd

# %%
# reading data from two CSV files, "climate_temp.csv" and "climate_precip.csv, and storing the data in two separate DataFrames named `climate_temp` and `climate_precip`, respectively.
climate_temp = pd.read_csv("climate_temp.csv")
climate_precip = pd.read_csv("climate_precip.csv")

# %%
climate_precip.head()
# Out:
#              STATION            STATION_NAME      DATE  DLY-PRCP-25PCTL  \
# 0  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100101            -6.66
# 1  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100102            -6.66
# 2  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100103            -6.66
# 3  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100104            -6.66
# 4  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100105            -6.66
#
#    DLY-SNWD-25PCTL  DLY-SNOW-25PCTL  DLY-PRCP-50PCTL  DLY-SNWD-50PCTL  \
# 0             -666            -66.6            -6.66             -666
# 1             -666            -66.6            -6.66             -666
# 2             -666            -66.6            -6.66             -666
# 3            -9999          -9999.0            -6.66            -9999
# 4            -9999          -9999.0            -6.66            -9999
#
#    DLY-SNOW-50PCTL  DLY-PRCP-75PCTL  ...  DLY-PRCP-PCTALL-GE100HI  \
# ...

# %%
climate_temp.head()
# Out:
#              STATION            STATION_NAME ELEVATION  LATITUDE   LONGITUDE  \
# 0  GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806  -116.03694
# 1  GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806  -116.03694
# 2  GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806  -116.03694
# 3  GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806  -116.03694
# 4  GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806  -116.03694
#
#        DATE  DLY-CLDD-BASE45  DLY-CLDD-BASE50  DLY-CLDD-BASE55  \
# 0  20100101                6                2            -7777
# 1  20100102                6                2                1
# 2  20100103                6                2                1
# 3  20100104                6                2                1
# 4  20100105                6                2                1
#
#    DLY-CLDD-BASE57  ...  DLY-CLDD-NORMAL  DLY-CLDD-BASE70  DLY-CLDD-BASE72  \
# ...

# %%
climate_temp.shape
# Out:
# (127020, 21)

# %%
climate_precip.shape
# Out:
# (151110, 29)

# %%
climate_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127020 entries, 0 to 127019
# Data columns (total 21 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   STATION          127020 non-null  object
#  1   STATION_NAME     127020 non-null  object
#  2   ELEVATION        127020 non-null  object
#  3   LATITUDE         127020 non-null  object
#  4   LONGITUDE        127020 non-null  object
#  5   DATE             127020 non-null  int64
#  6   DLY-CLDD-BASE45  127020 non-null  int64
#  7   DLY-CLDD-BASE50  127020 non-null  int64
#  8   DLY-CLDD-BASE55  127020 non-null  int64
#  9   DLY-CLDD-BASE57  127020 non-null  int64
#  10  DLY-CLDD-BASE60  127020 non-null  int64
#  11  DLY-CLDD-NORMAL  127020 non-null  int64
#  12  DLY-CLDD-BASE70  127020 non-null  int64
#  13  DLY-CLDD-BASE72  127020 non-null  int64
#  14  DLY-HTDD-BASE40  127020 non-null  int64
#  15  DLY-HTDD-BASE45  127020 non-null  int64
# ...

# %%
climate_precip.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151110 entries, 0 to 151109
# Data columns (total 29 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   STATION                  151110 non-null  object
#  1   STATION_NAME             151110 non-null  object
#  2   DATE                     151110 non-null  int64
#  3   DLY-PRCP-25PCTL          151110 non-null  float64
#  4   DLY-SNWD-25PCTL          151110 non-null  int64
#  5   DLY-SNOW-25PCTL          151110 non-null  float64
#  6   DLY-PRCP-50PCTL          151110 non-null  float64
#  7   DLY-SNWD-50PCTL          151110 non-null  int64
#  8   DLY-SNOW-50PCTL          151110 non-null  float64
#  9   DLY-PRCP-75PCTL          151110 non-null  float64
#  10  DLY-SNWD-75PCTL          151110 non-null  int64
#  11  DLY-SNOW-75PCTL          151110 non-null  float64
#  12  MTD-PRCP-NORMAL          151110 non-null  float64
# ...

# %%
climate_temp.describe()
# Out:
#                DATE  DLY-CLDD-BASE45  DLY-CLDD-BASE50  DLY-CLDD-BASE55  \
# count  1.270200e+05    127020.000000    127020.000000    127020.000000
# mean   2.010067e+07      -305.681680      -571.357164     -1364.776594
# std    3.450032e+02      1550.917511      2050.944179      2968.682933
# min    2.010010e+07     -7777.000000     -7777.000000     -7777.000000
# 25%    2.010040e+07         7.000000         3.000000         1.000000
# 50%    2.010070e+07        14.000000         9.000000         5.000000
# 75%    2.010100e+07        23.000000        18.000000        13.000000
# max    2.010123e+07        58.000000        53.000000        48.000000
#
#        DLY-CLDD-BASE57  DLY-CLDD-BASE60  DLY-CLDD-NORMAL  DLY-CLDD-BASE70  \
# count    127020.000000    127020.000000    127020.000000    127020.000000
# mean      -1610.030515     -1993.233766     -2300.983097     -2409.871020
# std        3159.342811      3401.256167      3553.088077      3598.276966
# ...

# %%
climate_precip.describe()
# Out:
#                DATE  DLY-PRCP-25PCTL  DLY-SNWD-25PCTL  DLY-SNOW-25PCTL  \
# count  1.511100e+05    151110.000000    151110.000000    151110.000000
# mean   2.010067e+07     -1983.400927     -9099.834584     -8477.923237
# std    3.450030e+02      3984.261185      2786.079371      3579.071334
# min    2.010010e+07     -9999.000000     -9999.000000     -9999.000000
# 25%    2.010040e+07        -6.660000     -9999.000000     -9999.000000
# 50%    2.010070e+07        -6.660000     -9999.000000     -9999.000000
# 75%    2.010100e+07         0.060000     -9999.000000     -9999.000000
# max    2.010123e+07         0.290000        40.000000         2.000000
#
#        DLY-PRCP-50PCTL  DLY-SNWD-50PCTL  DLY-SNOW-50PCTL  DLY-PRCP-75PCTL  \
# count    151110.000000    151110.000000    151110.000000    151110.000000
# mean      -1983.332954     -9099.703084     -8477.890501     -1983.185442
# std        3984.295025      2786.509451      3579.148894      3984.368470
# ...

# %%
climate_temp.isna().sum()
# Out:
# STATION            0
# STATION_NAME       0
# ELEVATION          0
# LATITUDE           0
# LONGITUDE          0
# DATE               0
# DLY-CLDD-BASE45    0
# DLY-CLDD-BASE50    0
# DLY-CLDD-BASE55    0
# DLY-CLDD-BASE57    0
# DLY-CLDD-BASE60    0
# DLY-CLDD-NORMAL    0
# DLY-CLDD-BASE70    0
# DLY-CLDD-BASE72    0
# DLY-HTDD-BASE40    0
# DLY-HTDD-BASE45    0
# DLY-HTDD-BASE50    0
# DLY-HTDD-BASE55    0
# DLY-HTDD-BASE57    0
# DLY-HTDD-BASE60    0
# DLY-HTDD-NORMAL    0
# dtype: int64

# %%
climate_precip.isna().sum()
# Out:
# STATION                    0
# STATION_NAME               0
# DATE                       0
# DLY-PRCP-25PCTL            0
# DLY-SNWD-25PCTL            0
# DLY-SNOW-25PCTL            0
# DLY-PRCP-50PCTL            0
# DLY-SNWD-50PCTL            0
# DLY-SNOW-50PCTL            0
# DLY-PRCP-75PCTL            0
# DLY-SNWD-75PCTL            0
# DLY-SNOW-75PCTL            0
# MTD-PRCP-NORMAL            0
# MTD-SNOW-NORMAL            0
# YTD-PRCP-NORMAL            0
# YTD-SNOW-NORMAL            0
# DLY-PRCP-PCTALL-GE001HI    0
# DLY-PRCP-PCTALL-GE010HI    0
# DLY-PRCP-PCTALL-GE050HI    0
# DLY-PRCP-PCTALL-GE100HI    0
# DLY-SNWD-PCTALL-GE001WI    0
# DLY-SNWD-PCTALL-GE010WI    0
# DLY-SNWD-PCTALL-GE003WI    0
# DLY-SNWD-PCTALL-GE005WI    0
# DLY-SNOW-PCTALL-GE001TI    0
# DLY-SNOW-PCTALL-GE010TI    0
# DLY-SNOW-PCTALL-GE100TI    0
# DLY-SNOW-PCTALL-GE030TI    0
# DLY-SNOW-PCTALL-GE050TI    0
# dtype: int64

# %%
# creating a subset of the DataFrame `climate_precip` where the value in the 'STATION' column is equal to 'GHCND:USC00045721'. The subset_precip DataFrame will only contain rows where the 'STATION' column matches the specified station ID 'GHCND:USC00045721'.
subset_precip = climate_precip[climate_precip['STATION'] == 'GHCND:USC00045721']

# performing an inner merge between two DataFrames, `subset_precip` and `climate_temp`, based on the columns 'STATION' and 'DATE'. The resulting DataFrame `merged_inner` will contain only the rows where the values in both 'STATION' and 'DATE' columns match in both DataFrames.
merged_inner = pd.merge(subset_precip, climate_temp, on=['STATION', 'DATE'], how='inner')

# %%
print(merged_inner.shape)
merged_inner.head()
# Out:
# (365, 48)
#              STATION          STATION_NAME_x      DATE  DLY-PRCP-25PCTL  \
# 0  GHCND:USC00045721  MITCHELL CAVERNS CA US  20100101             0.04
# 1  GHCND:USC00045721  MITCHELL CAVERNS CA US  20100102             0.05
# 2  GHCND:USC00045721  MITCHELL CAVERNS CA US  20100103             0.05
# 3  GHCND:USC00045721  MITCHELL CAVERNS CA US  20100104             0.05
# 4  GHCND:USC00045721  MITCHELL CAVERNS CA US  20100105             0.05
#
#    DLY-SNWD-25PCTL  DLY-SNOW-25PCTL  DLY-PRCP-50PCTL  DLY-SNWD-50PCTL  \
# 0             -666            -66.6             0.16             -666
# 1             -666            -66.6             0.16             -666
# 2             -666            -66.6             0.16             -666
# 3             -666            -66.6             0.16             -666
# 4             -666            -66.6             0.17             -666
#
#    DLY-SNOW-50PCTL  DLY-PRCP-75PCTL  ...  DLY-CLDD-NORMAL  DLY-CLDD-BASE70  \
# ...

# %%
# merging two pandas DataFrames, `climate_precip` and `climate_temp`, based on the columns 'STATION' and 'DATE' using an inner join. The resulting DataFrame, `merged_full_inner`, will contain only the rows where there are matching values in both DataFrames for the specified columns.
merged_full_inner = pd.merge(climate_precip, climate_temp, on=['STATION', 'DATE'], how='inner')
print(merged_full_inner.shape)
merged_full_inner.head()
# Out:
# (123005, 48)
#              STATION          STATION_NAME_x      DATE  DLY-PRCP-25PCTL  \
# 0  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100101            -6.66
# 1  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100102            -6.66
# 2  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100103            -6.66
# 3  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100104            -6.66
# 4  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100105            -6.66
#
#    DLY-SNWD-25PCTL  DLY-SNOW-25PCTL  DLY-PRCP-50PCTL  DLY-SNWD-50PCTL  \
# 0             -666            -66.6            -6.66             -666
# 1             -666            -66.6            -6.66             -666
# 2             -666            -66.6            -6.66             -666
# 3            -9999          -9999.0            -6.66            -9999
# 4            -9999          -9999.0            -6.66            -9999
#
#    DLY-SNOW-50PCTL  DLY-PRCP-75PCTL  ...  DLY-CLDD-NORMAL  DLY-CLDD-BASE70  \
# ...

# %%
# merging two pandas DataFrames, `subset_precip` and `climate_temp`, based on the columns 'STATION' and 'DATE' using an outer join. The resulting DataFrame `merged_outer` will contain all rows from both DataFrames, with missing values filled in with NaN where there is no match between the 'STATION' and 'DATE' columns.
merged_outer = pd.merge(subset_precip, climate_temp, on=['STATION', 'DATE'], how='outer')
merged_outer.shape
# Out:
# (127020, 48)

# %%
merged_outer.head()
# Out:
#              STATION          STATION_NAME_x      DATE  DLY-PRCP-25PCTL  \
# 0  GHCND:USC00045721  MITCHELL CAVERNS CA US  20100101             0.04
# 1  GHCND:USC00045721  MITCHELL CAVERNS CA US  20100102             0.05
# 2  GHCND:USC00045721  MITCHELL CAVERNS CA US  20100103             0.05
# 3  GHCND:USC00045721  MITCHELL CAVERNS CA US  20100104             0.05
# 4  GHCND:USC00045721  MITCHELL CAVERNS CA US  20100105             0.05
#
#    DLY-SNWD-25PCTL  DLY-SNOW-25PCTL  DLY-PRCP-50PCTL  DLY-SNWD-50PCTL  \
# 0           -666.0            -66.6             0.16           -666.0
# 1           -666.0            -66.6             0.16           -666.0
# 2           -666.0            -66.6             0.16           -666.0
# 3           -666.0            -66.6             0.16           -666.0
# 4           -666.0            -66.6             0.17           -666.0
#
#    DLY-SNOW-50PCTL  DLY-PRCP-75PCTL  ...  DLY-CLDD-NORMAL  DLY-CLDD-BASE70  \
# ...

# %%
# merging two pandas DataFrames, `climate_temp` and `subset_precip`, based on the columns 'STATION' and 'DATE'. The parameter `how='left'` specifies that it is a left join, meaning all the rows from the `climate_temp` DataFrame will be included in the merged DataFrame, with matching rows from `subset_precip` appended where available.
merged_left = pd.merge(climate_temp, subset_precip, on=['STATION', 'DATE'], how='left')
print(merged_left.shape)
merged_left.head()
# Out:
# (127020, 48)
#              STATION          STATION_NAME_x ELEVATION  LATITUDE   LONGITUDE  \
# 0  GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806  -116.03694
# 1  GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806  -116.03694
# 2  GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806  -116.03694
# 3  GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806  -116.03694
# 4  GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806  -116.03694
#
#        DATE  DLY-CLDD-BASE45  DLY-CLDD-BASE50  DLY-CLDD-BASE55  \
# 0  20100101                6                2            -7777
# 1  20100102                6                2                1
# 2  20100103                6                2                1
# 3  20100104                6                2                1
# 4  20100105                6                2                1
#
#    DLY-CLDD-BASE57  ...  DLY-PRCP-PCTALL-GE100HI  DLY-SNWD-PCTALL-GE001WI  \
# ...

# %%
# performing a right merge operation using the pandas library. It is merging two DataFrames, subset_precip and climate_temp, based on the columns 'STATION' and 'DATE'. The 'how='right'' parameter specifies that it is a right merge, meaning that all the rows from the climate_temp DataFrame will be included in the merged DataFrame, with matching rows from subset_precip added where available.
merged_right = pd.merge(subset_precip, climate_temp, on=['STATION', 'DATE'], how='right')
print(merged_right.shape)
merged_right.head()
# Out:
# (127020, 48)
#              STATION STATION_NAME_x      DATE  DLY-PRCP-25PCTL  \
# 0  GHCND:USC00049099            NaN  20100101              NaN
# 1  GHCND:USC00049099            NaN  20100102              NaN
# 2  GHCND:USC00049099            NaN  20100103              NaN
# 3  GHCND:USC00049099            NaN  20100104              NaN
# 4  GHCND:USC00049099            NaN  20100105              NaN
#
#    DLY-SNWD-25PCTL  DLY-SNOW-25PCTL  DLY-PRCP-50PCTL  DLY-SNWD-50PCTL  \
# 0              NaN              NaN              NaN              NaN
# 1              NaN              NaN              NaN              NaN
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
# 4              NaN              NaN              NaN              NaN
#
#    DLY-SNOW-50PCTL  DLY-PRCP-75PCTL  ...  DLY-CLDD-NORMAL  DLY-CLDD-BASE70  \
# ...

# %%
# setting the index of the `climate_temp` DataFrame to be a multi-level index consisting of the columns 'STATION' and 'DATE'.
climate_temp = climate_temp.set_index(['STATION','DATE'])
print(climate_temp.shape)
climate_temp.head()
# Out:
# (127020, 19)
#                                       STATION_NAME ELEVATION  LATITUDE  \
# STATION           DATE
# GHCND:USC00049099 20100101  TWENTYNINE PALMS CA US       602  34.12806
#                   20100102  TWENTYNINE PALMS CA US       602  34.12806
#                   20100103  TWENTYNINE PALMS CA US       602  34.12806
#                   20100104  TWENTYNINE PALMS CA US       602  34.12806
#                   20100105  TWENTYNINE PALMS CA US       602  34.12806
#
#                              LONGITUDE  DLY-CLDD-BASE45  DLY-CLDD-BASE50  \
# STATION           DATE
# GHCND:USC00049099 20100101  -116.03694                6                2
#                   20100102  -116.03694                6                2
#                   20100103  -116.03694                6                2
#                   20100104  -116.03694                6                2
#                   20100105  -116.03694                6                2
#
# ...

# %%
# setting the index of the DataFrame `climate_precip` to be a MultiIndex with columns 'STATION' and 'DATE'. It then prints the shape of the DataFrame and displays the first few rows using the `head()` function. This operation allows for easier access and manipulation of the data based on the 'STATION' and 'DATE' columns.
climate_precip = climate_precip.set_index(['STATION','DATE'])
print(climate_precip.shape)
climate_precip.head()
# Out:
# (151110, 27)
#                                       STATION_NAME  DLY-PRCP-25PCTL  \
# STATION           DATE
# GHCND:USC00049099 20100101  TWENTYNINE PALMS CA US            -6.66
#                   20100102  TWENTYNINE PALMS CA US            -6.66
#                   20100103  TWENTYNINE PALMS CA US            -6.66
#                   20100104  TWENTYNINE PALMS CA US            -6.66
#                   20100105  TWENTYNINE PALMS CA US            -6.66
#
#                             DLY-SNWD-25PCTL  DLY-SNOW-25PCTL  DLY-PRCP-50PCTL  \
# STATION           DATE
# GHCND:USC00049099 20100101             -666            -66.6            -6.66
#                   20100102             -666            -66.6            -6.66
#                   20100103             -666            -66.6            -6.66
#                   20100104            -9999          -9999.0            -6.66
#                   20100105            -9999          -9999.0            -6.66
#
# ...

# %%
# performing a join operation between two DataFrames `climate_temp` and `climate_precip` based on the columns 'STATION' and 'DATE'. The `lsuffix='_left'` and `rsuffix='_right'` parameters are used to differentiate columns with the same name in the two DataFrames after the join operation.
join_ = climate_temp.join(climate_precip, on = ['STATION', 'DATE'], lsuffix='_left', rsuffix='_right')
print(join_.shape)
join_.head()
# Out:
# (127020, 46)
#                                  STATION_NAME_left ELEVATION  LATITUDE  \
# STATION           DATE
# GHCND:USC00049099 20100101  TWENTYNINE PALMS CA US       602  34.12806
#                   20100102  TWENTYNINE PALMS CA US       602  34.12806
#                   20100103  TWENTYNINE PALMS CA US       602  34.12806
#                   20100104  TWENTYNINE PALMS CA US       602  34.12806
#                   20100105  TWENTYNINE PALMS CA US       602  34.12806
#
#                              LONGITUDE  DLY-CLDD-BASE45  DLY-CLDD-BASE50  \
# STATION           DATE
# GHCND:USC00049099 20100101  -116.03694                6                2
#                   20100102  -116.03694                6                2
#                   20100103  -116.03694                6                2
#                   20100104  -116.03694                6                2
#                   20100105  -116.03694                6                2
#
# ...

# %%
join_
# Out:
#                                  STATION_NAME_left ELEVATION  LATITUDE  \
# STATION           DATE
# GHCND:USC00049099 20100101  TWENTYNINE PALMS CA US       602  34.12806
#                   20100102  TWENTYNINE PALMS CA US       602  34.12806
#                   20100103  TWENTYNINE PALMS CA US       602  34.12806
#                   20100104  TWENTYNINE PALMS CA US       602  34.12806
#                   20100105  TWENTYNINE PALMS CA US       602  34.12806
# ...                                            ...       ...       ...
# GHCND:USC00046006 20101227  MOUNT WILSON CBS CA US    1740.4   34.2308
#                   20101228  MOUNT WILSON CBS CA US    1740.4   34.2308
#                   20101229  MOUNT WILSON CBS CA US    1740.4   34.2308
#                   20101230  MOUNT WILSON CBS CA US    1740.4   34.2308
#                   20101231  MOUNT WILSON CBS CA US    1740.4   34.2308
#
#                              LONGITUDE  DLY-CLDD-BASE45  DLY-CLDD-BASE50  \
# ...

# %%
# concatenating the DataFrame `climate_temp` with itself along the rows (axis=0). This means that the rows of `climate_temp` will be duplicated in the resulting DataFrame `concate_row`.
concate_row = pd.concat([climate_temp, climate_temp], axis=0)
concate_row
# Out:
#                                       STATION_NAME ELEVATION  LATITUDE  \
# STATION           DATE
# GHCND:USC00049099 20100101  TWENTYNINE PALMS CA US       602  34.12806
#                   20100102  TWENTYNINE PALMS CA US       602  34.12806
#                   20100103  TWENTYNINE PALMS CA US       602  34.12806
#                   20100104  TWENTYNINE PALMS CA US       602  34.12806
#                   20100105  TWENTYNINE PALMS CA US       602  34.12806
# ...                                            ...       ...       ...
# GHCND:USC00046006 20101227  MOUNT WILSON CBS CA US    1740.4   34.2308
#                   20101228  MOUNT WILSON CBS CA US    1740.4   34.2308
#                   20101229  MOUNT WILSON CBS CA US    1740.4   34.2308
#                   20101230  MOUNT WILSON CBS CA US    1740.4   34.2308
#                   20101231  MOUNT WILSON CBS CA US    1740.4   34.2308
#
#                              LONGITUDE  DLY-CLDD-BASE45  DLY-CLDD-BASE50  \
# ...

# %%
# concatenating two DataFrames `climate_temp` horizontally along the columns axis. The `pd.concat()` function is used to concatenate DataFrames along a particular axis, and in this case, `axis=1` specifies that the concatenation should be done along the columns axis. The resulting DataFrame `concate_col` will have the columns of `climate_temp` repeated side by side.
concate_col = pd.concat([climate_temp, climate_temp], axis=1)
concate_col
# Out:
#                                       STATION_NAME ELEVATION  LATITUDE  \
# STATION           DATE
# GHCND:USC00049099 20100101  TWENTYNINE PALMS CA US       602  34.12806
#                   20100102  TWENTYNINE PALMS CA US       602  34.12806
#                   20100103  TWENTYNINE PALMS CA US       602  34.12806
#                   20100104  TWENTYNINE PALMS CA US       602  34.12806
#                   20100105  TWENTYNINE PALMS CA US       602  34.12806
# ...                                            ...       ...       ...
# GHCND:USC00046006 20101227  MOUNT WILSON CBS CA US    1740.4   34.2308
#                   20101228  MOUNT WILSON CBS CA US    1740.4   34.2308
#                   20101229  MOUNT WILSON CBS CA US    1740.4   34.2308
#                   20101230  MOUNT WILSON CBS CA US    1740.4   34.2308
#                   20101231  MOUNT WILSON CBS CA US    1740.4   34.2308
#
#                              LONGITUDE  DLY-CLDD-BASE45  DLY-CLDD-BASE50  \
# ...

# %%
# concatenating two DataFrames `climate_temp` along the columns axis (axis=1) using an inner join. This means that only the columns that are common between the two DataFrames will be included in the resulting DataFrame `concate_inner`.
concate_inner = pd.concat([climate_temp, climate_temp], join = 'inner', axis=1)
concate_inner
# Out:
#                                       STATION_NAME ELEVATION  LATITUDE  \
# STATION           DATE
# GHCND:USC00049099 20100101  TWENTYNINE PALMS CA US       602  34.12806
#                   20100102  TWENTYNINE PALMS CA US       602  34.12806
#                   20100103  TWENTYNINE PALMS CA US       602  34.12806
#                   20100104  TWENTYNINE PALMS CA US       602  34.12806
#                   20100105  TWENTYNINE PALMS CA US       602  34.12806
# ...                                            ...       ...       ...
# GHCND:USC00046006 20101227  MOUNT WILSON CBS CA US    1740.4   34.2308
#                   20101228  MOUNT WILSON CBS CA US    1740.4   34.2308
#                   20101229  MOUNT WILSON CBS CA US    1740.4   34.2308
#                   20101230  MOUNT WILSON CBS CA US    1740.4   34.2308
#                   20101231  MOUNT WILSON CBS CA US    1740.4   34.2308
#
#                              LONGITUDE  DLY-CLDD-BASE45  DLY-CLDD-BASE50  \
# ...

# %%
# concatenating the DataFrames `climate_temp` twice along a new hierarchical index created by the keys 'Temperature' and 'Precipitation'. This means that the resulting DataFrame will have two levels of index - the first level will be 'Temperature' and 'Precipitation', and the second level will be the original index of the `climate_temp` DataFrame.
concate_keys = pd.concat([climate_temp, climate_temp], keys=['Temperature', 'Precipitation'])
concate_keys
# Out:
#                                                     STATION_NAME ELEVATION  \
#               STATION           DATE
# Temperature   GHCND:USC00049099 20100101  TWENTYNINE PALMS CA US       602
#                                 20100102  TWENTYNINE PALMS CA US       602
#                                 20100103  TWENTYNINE PALMS CA US       602
#                                 20100104  TWENTYNINE PALMS CA US       602
#                                 20100105  TWENTYNINE PALMS CA US       602
# ...                                                          ...       ...
# Precipitation GHCND:USC00046006 20101227  MOUNT WILSON CBS CA US    1740.4
#                                 20101228  MOUNT WILSON CBS CA US    1740.4
#                                 20101229  MOUNT WILSON CBS CA US    1740.4
#                                 20101230  MOUNT WILSON CBS CA US    1740.4
#                                 20101231  MOUNT WILSON CBS CA US    1740.4
#
# ...

# %% [markdown]
# # **ANALYSIS AND VISULAIZATION**

# %%
if climate_precip['STATION_NAME'].unique().sort() == climate_temp['STATION_NAME'].unique().sort():
    print(climate_precip['STATION_NAME'].unique().sort())
else:
    print(False)
# Out:
# True

# %%
climate_precip = climate_precip.reset_index()
climate_temp = climate_temp.reset_index()
concate_outer = pd.concat([climate_temp, climate_precip], join='outer', axis= 1)

# %%
climate_precip
# Out:
#                   STATION      DATE            STATION_NAME  DLY-PRCP-25PCTL  \
# 0       GHCND:USC00049099  20100101  TWENTYNINE PALMS CA US            -6.66
# 1       GHCND:USC00049099  20100102  TWENTYNINE PALMS CA US            -6.66
# 2       GHCND:USC00049099  20100103  TWENTYNINE PALMS CA US            -6.66
# 3       GHCND:USC00049099  20100104  TWENTYNINE PALMS CA US            -6.66
# 4       GHCND:USC00049099  20100105  TWENTYNINE PALMS CA US            -6.66
# ...                   ...       ...                     ...              ...
# 151105  GHCND:USC00046006  20101227  MOUNT WILSON CBS CA US             0.12
# 151106  GHCND:USC00046006  20101228  MOUNT WILSON CBS CA US             0.12
# 151107  GHCND:USC00046006  20101229  MOUNT WILSON CBS CA US             0.12
# 151108  GHCND:USC00046006  20101230  MOUNT WILSON CBS CA US             0.12
# 151109  GHCND:USC00046006  20101231  MOUNT WILSON CBS CA US             0.12
#
# ...

# %%
climate_temp
# Out:
#                   STATION      DATE            STATION_NAME ELEVATION  \
# 0       GHCND:USC00049099  20100101  TWENTYNINE PALMS CA US       602
# 1       GHCND:USC00049099  20100102  TWENTYNINE PALMS CA US       602
# 2       GHCND:USC00049099  20100103  TWENTYNINE PALMS CA US       602
# 3       GHCND:USC00049099  20100104  TWENTYNINE PALMS CA US       602
# 4       GHCND:USC00049099  20100105  TWENTYNINE PALMS CA US       602
# ...                   ...       ...                     ...       ...
# 127015  GHCND:USC00046006  20101227  MOUNT WILSON CBS CA US    1740.4
# 127016  GHCND:USC00046006  20101228  MOUNT WILSON CBS CA US    1740.4
# 127017  GHCND:USC00046006  20101229  MOUNT WILSON CBS CA US    1740.4
# 127018  GHCND:USC00046006  20101230  MOUNT WILSON CBS CA US    1740.4
# 127019  GHCND:USC00046006  20101231  MOUNT WILSON CBS CA US    1740.4
#
#         LATITUDE   LONGITUDE  DLY-CLDD-BASE45  DLY-CLDD-BASE50  \
# ...

# %%
concate_outer
# Out:
#                   STATION        DATE            STATION_NAME ELEVATION  \
# 0       GHCND:USC00049099  20100101.0  TWENTYNINE PALMS CA US       602
# 1       GHCND:USC00049099  20100102.0  TWENTYNINE PALMS CA US       602
# 2       GHCND:USC00049099  20100103.0  TWENTYNINE PALMS CA US       602
# 3       GHCND:USC00049099  20100104.0  TWENTYNINE PALMS CA US       602
# 4       GHCND:USC00049099  20100105.0  TWENTYNINE PALMS CA US       602
# ...                   ...         ...                     ...       ...
# 151105                NaN         NaN                     NaN       NaN
# 151106                NaN         NaN                     NaN       NaN
# 151107                NaN         NaN                     NaN       NaN
# 151108                NaN         NaN                     NaN       NaN
# 151109                NaN         NaN                     NaN       NaN
#
#         LATITUDE   LONGITUDE  DLY-CLDD-BASE45  DLY-CLDD-BASE50  \
# ...

# %%
concate_outer.shape
# Out:
# (151110, 50)

# %%
concate_outer.columns
# Out:
# Index(['STATION', 'DATE', 'STATION_NAME', 'ELEVATION', 'LATITUDE', 'LONGITUDE',
#        'DLY-CLDD-BASE45', 'DLY-CLDD-BASE50', 'DLY-CLDD-BASE55',
#        'DLY-CLDD-BASE57', 'DLY-CLDD-BASE60', 'DLY-CLDD-NORMAL',
#        'DLY-CLDD-BASE70', 'DLY-CLDD-BASE72', 'DLY-HTDD-BASE40',
#        'DLY-HTDD-BASE45', 'DLY-HTDD-BASE50', 'DLY-HTDD-BASE55',
#        'DLY-HTDD-BASE57', 'DLY-HTDD-BASE60', 'DLY-HTDD-NORMAL', 'STATION',
#        'DATE', 'STATION_NAME', 'DLY-PRCP-25PCTL', 'DLY-SNWD-25PCTL',
#        'DLY-SNOW-25PCTL', 'DLY-PRCP-50PCTL', 'DLY-SNWD-50PCTL',
#        'DLY-SNOW-50PCTL', 'DLY-PRCP-75PCTL', 'DLY-SNWD-75PCTL',
#        'DLY-SNOW-75PCTL', 'MTD-PRCP-NORMAL', 'MTD-SNOW-NORMAL',
#        'YTD-PRCP-NORMAL', 'YTD-SNOW-NORMAL', 'DLY-PRCP-PCTALL-GE001HI',
#        'DLY-PRCP-PCTALL-GE010HI', 'DLY-PRCP-PCTALL-GE050HI',
#        'DLY-PRCP-PCTALL-GE100HI', 'DLY-SNWD-PCTALL-GE001WI',
#        'DLY-SNWD-PCTALL-GE010WI', 'DLY-SNWD-PCTALL-GE003WI',
# ...

# %%
concate_outer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151110 entries, 0 to 151109
# Data columns (total 50 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   STATION                  127020 non-null  object
#  1   DATE                     127020 non-null  float64
#  2   STATION_NAME             127020 non-null  object
#  3   ELEVATION                127020 non-null  object
#  4   LATITUDE                 127020 non-null  object
#  5   LONGITUDE                127020 non-null  object
#  6   DLY-CLDD-BASE45          127020 non-null  float64
#  7   DLY-CLDD-BASE50          127020 non-null  float64
#  8   DLY-CLDD-BASE55          127020 non-null  float64
#  9   DLY-CLDD-BASE57          127020 non-null  float64
#  10  DLY-CLDD-BASE60          127020 non-null  float64
#  11  DLY-CLDD-NORMAL          127020 non-null  float64
#  12  DLY-CLDD-BASE70          127020 non-null  float64
# ...

# %%
concate_outer.isna().sum()
# Out:
# STATION                    24090
# DATE                       24090
# STATION_NAME               24090
# ELEVATION                  24090
# LATITUDE                   24090
# LONGITUDE                  24090
# DLY-CLDD-BASE45            24090
# DLY-CLDD-BASE50            24090
# DLY-CLDD-BASE55            24090
# DLY-CLDD-BASE57            24090
# DLY-CLDD-BASE60            24090
# DLY-CLDD-NORMAL            24090
# DLY-CLDD-BASE70            24090
# DLY-CLDD-BASE72            24090
# DLY-HTDD-BASE40            24090
# DLY-HTDD-BASE45            24090
# DLY-HTDD-BASE50            24090
# DLY-HTDD-BASE55            24090
# DLY-HTDD-BASE57            24090
# DLY-HTDD-BASE60            24090
# DLY-HTDD-NORMAL            24090
# STATION                        0
# DATE                           0
# STATION_NAME                   0
# DLY-PRCP-25PCTL                0
# DLY-SNWD-25PCTL                0
# DLY-SNOW-25PCTL                0
# DLY-PRCP-50PCTL                0
# ...

# %%
concate_outer.isnull().sum()
# Out:
# STATION                    24090
# DATE                       24090
# STATION_NAME               24090
# ELEVATION                  24090
# LATITUDE                   24090
# LONGITUDE                  24090
# DLY-CLDD-BASE45            24090
# DLY-CLDD-BASE50            24090
# DLY-CLDD-BASE55            24090
# DLY-CLDD-BASE57            24090
# DLY-CLDD-BASE60            24090
# DLY-CLDD-NORMAL            24090
# DLY-CLDD-BASE70            24090
# DLY-CLDD-BASE72            24090
# DLY-HTDD-BASE40            24090
# DLY-HTDD-BASE45            24090
# DLY-HTDD-BASE50            24090
# DLY-HTDD-BASE55            24090
# DLY-HTDD-BASE57            24090
# DLY-HTDD-BASE60            24090
# DLY-HTDD-NORMAL            24090
# STATION                        0
# DATE                           0
# STATION_NAME                   0
# DLY-PRCP-25PCTL                0
# DLY-SNWD-25PCTL                0
# DLY-SNOW-25PCTL                0
# DLY-PRCP-50PCTL                0
# ...

# %%
concate_outer.duplicated().sum()
# Out:
# 0

# %%
concate_outer.describe()
# Out:
#                DATE  DLY-CLDD-BASE45  DLY-CLDD-BASE50  DLY-CLDD-BASE55  \
# count  1.270200e+05    127020.000000    127020.000000    127020.000000
# mean   2.010067e+07      -305.681680      -571.357164     -1364.776594
# std    3.450032e+02      1550.917511      2050.944179      2968.682933
# min    2.010010e+07     -7777.000000     -7777.000000     -7777.000000
# 25%    2.010040e+07         7.000000         3.000000         1.000000
# 50%    2.010070e+07        14.000000         9.000000         5.000000
# 75%    2.010100e+07        23.000000        18.000000        13.000000
# max    2.010123e+07        58.000000        53.000000        48.000000
#
#        DLY-CLDD-BASE57  DLY-CLDD-BASE60  DLY-CLDD-NORMAL  DLY-CLDD-BASE70  \
# count    127020.000000    127020.000000    127020.000000    127020.000000
# mean      -1610.030515     -1993.233766     -2300.983097     -2409.871020
# std        3159.342811      3401.256167      3553.088077      3598.276966
# ...

# %%
concate_outer.to_csv(r"E:\\College\\LnB\\final.csv")
